# %%
import pandas as pd

# %%
csv_file = "bc_trip259172515_230215.csv"
df = pd.read_csv(csv_file)

# %%
print("Number of breadcrumb records:", len(df))

# %%
print("Column names in the dataset:")
print(df.columns)

# %%
df = df.drop(columns=["EVENT_NO_STOP", "GPS_SATELLITES", "GPS_HDOP"], errors="ignore")
df.head()

# %%
df['TIMESTAMP'] = pd.to_datetime(df['TIMESTAMP'], unit='s')

# %%
import pandas as pd

# Define only the columns you want to keep
columns_to_use = [
    "TIMESTAMP", "VEHICLE_ID", "LATITUDE", "LONGITUDE", "HEADING", "SPEED"
]

# Read only these columns from the CSV
df = pd.read_csv("bc_trip259172515_230215.csv", usecols=columns_to_use)

# Preview to confirm
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 9
#       4 columns_to_use = [
#       5     "TIMESTAMP", "VEHICLE_ID", "LATITUDE", "LONGITUDE", "HEADING", "SPEED"
#       6 ]
#       8 # Read only these columns from the CSV
# ----> 9 df = pd.read_csv("bc_trip259172515_230215.csv", usecols=columns_to_use)
#      11 # Preview to confirm
#      12 print(df.head())
#
# ...
